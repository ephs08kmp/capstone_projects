# %% [markdown]
# # Frac Production Analysis

# %%
# Necessary imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Production Reports
# Note: This is the Colorado well production updated monthly until the end of 2017, broken out by individual well and by production month.
# Data Source: [COGCC Production Summary Data](https://cogcc.state.co.us/documents/data/downloads/production/co%202017%20Annual%20Production%20Summary-xp.zip)

# %%
df = pd.read_csv('2017_prod_reports.csv')
print(df.shape)
df.tail()
# Out:
# (857203, 33)
#         report_month  report_year  ST  api_county_code  api_seq_num  \
# 857198            12         2016   5              125        12123
# 857199            12         2016   5              125        12124
# 857200            12         2016   5              125        12125
# 857201            12         2016   5              125        12126
# 857202            12         2017   5               43         6226
#
#         sidetrack_num formation_code well_status  prod_days water_disp_code  \
# 857198              0           NBRR          PR       31.0               C
# 857199              0           NBRR          PR       31.0               P
# 857200              0           NBRR          PR       31.0               C
# 857201              0           NBRR          PR       31.0               C
# 857202              1           NBRR          TA        0.0             NaN
#
#          ...     gas_prod  btu_sales  gas_press_tbg  gas_press_csg  \
# 857198   ...       2225.0     1000.0            NaN            NaN
# 857199   ...       2364.0      992.0            NaN            NaN
# 857200   ...        633.0     1000.0            NaN            NaN
# 857201   ...       1202.0      996.0            NaN            NaN
# 857202   ...          NaN        NaN            NaN            NaN
#
#         operator_num                           name       facility_name  \
# 857198         10489  AUGUSTUS ENERGY RESOURCES LLC       Gardner Trust
# 857199         66190           OMIMEX PETROLEUM INC  Fiddler Peak Ranch
# 857200         10489  AUGUSTUS ENERGY RESOURCES LLC             Chapman
# 857201         10489  AUGUSTUS ENERGY RESOURCES LLC          Haven Hill
# 857202         10412            AUSCO PETROLEUM INC              Hudson
#
#         facility_num                  accepted_date  revised
# 857198   44-18 2N46W  2017-02-07 14:43:50.530000000      NaN
# 857199      4-3-5-45  2017-01-12 16:10:23.057000000      NaN
# 857200   13-19 1S44W  2017-02-07 14:43:50.530000000      NaN
# 857201   14-15 4N47W  2017-02-07 14:43:50.530000000      NaN
# 857202             1  2017-12-27 14:58:21.907000000      NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# Let's check for what columns I am dealing with here, along with how many non-null values I have to work with.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857203 entries, 0 to 857202
# Data columns (total 33 columns):
# report_month       857203 non-null int64
# report_year        857203 non-null int64
# ST                 857203 non-null int64
# api_county_code    857203 non-null int64
# api_seq_num        857203 non-null int64
# sidetrack_num      857203 non-null int64
# formation_code     857203 non-null object
# well_status        857203 non-null object
# prod_days          825707 non-null float64
# water_disp_code    454823 non-null object
# water_vol          443316 non-null float64
# water_press_tbg    240511 non-null float64
# water_press_csg    235473 non-null float64
# bom_invent         489472 non-null float64
# oil_vol            378131 non-null float64
# oil_sales          301069 non-null float64
# adjustment         50065 non-null float64
# eom_invent         487351 non-null float64
# gravity_sales      301097 non-null float64
# gas_sales          593103 non-null float64
# flared             42414 non-null float64
# gas_vol            348661 non-null float64
# shrink             46888 non-null float64
# gas_prod           604478 non-null float64
# btu_sales          595390 non-null float64
# gas_press_tbg      230335 non-null float64
# gas_press_csg      231518 non-null float64
# operator_num       857203 non-null int64
# name               857203 non-null object
# facility_name      857203 non-null object
# facility_num       857095 non-null object
# accepted_date      857203 non-null object
# revised            0 non-null float64
# dtypes: float64(19), int64(7), object(7)
# memory usage: 215.8+ MB

# %% [markdown]
# Most of this data is complete for the well information, but a lot of the specific values are missing, leaving approximiately 240K months of production to be analyzed. Let's see if the other sources are any better.
#
# ## Frac and Well Data
# This data was provided by Jeffrey A. Beunier of Front Range Energy Partners, via the Drilling Info site.  I still haven't been provided any more details about this data, so that's all I know for now.
# ### Data Indices
# This first set of data contains all of the headers for each of the provided datasets.

# %%
indices = pd.read_excel('1a_Frac_Capstone/DATA_EXPORT_INDEX.xlsx', usecols=(5, 6, 7, 8, 9))
print(indices.shape)
indices
# Out:
# (105, 5)
#                      WELL HEADER DATA     PRODUCTION HEADER DATA  \
# 0                               API10                        NaN
# 1                               API12                    API/UWI
# 2                               API14             Operator Alias
# 3                           Well Name            Well/Lease Name
# 4                         Well Number                Well Number
# 5                          Lease Name                Entity Type
# 6                      Operator Alias              County/Parish
# 7                   Reported Operator                  Reservoir
# 8                               Field            Production Type
# 9                       County/Parish           Producing Status
# 10                   Target Formation                 Drill Type
# 11                    DI Landing Zone            First Prod Date
# 12                       KB Elevation             Last Prod Date
# 13                   Ground Elevation                    Cum Gas
# 14                Measured Depth (TD)                    Cum Oil
# 15                True Vertical Depth                    Cum BOE
# 16                    Production Type                  Cum Water
# 17                        Well Status                 Cum MMCFGE
# 18                          Spud Date                  Cum BCFGE
# 19                    Completion Date                  Daily Gas
# 20                         Drill Type                  Daily Oil
# 21                  Upper Perforation            First Month Oil
# 22                  Lower Perforation            First Month Gas
# 23          Gross Perforated Interval          First Month Water
# 24                  Horizontal Length                First 6 Oil
# 25             Wellbore Count (API10)                First 6 Gas
# 26           Completion Count (API10)                First 6 BOE
# 27        Treatment Job Count (API10)              First 6 Water
# 28                    First Prod Date               First 12 Oil
# 29   Start Date (First Treatment Job)               First 12 Gas
# ..                                ...                        ...
# 75                       First 60 Gas                 Well Count
# 76                       First 60 Oil           Max Active Wells
# 77                     First 60 Water            Months Produced
# 78     Has Digitized Trajectory (Y/N)               Gas Gatherer
# 79           Has Well Log (LAS) (Y/N)               Oil Gatherer
# 80        Has Well Log (Raster) (Y/N)               Lease Number
# 81                      LAS Mnemonics                  Spud Date
# 82                            Country        Measured Depth (TD)
# 83                              Basin        True Vertical Depth
# 84              Play Assessment Basin  Gross Perforated Interval
# 85                              State                      Field
# 86                            Section                      State
# 87                           Township                   District
# 88                              Range                      Basin
# 89                    Quarter Quarter                    Country
# 90                           District                    Section
# 91                           Abstract                   Township
# 92                              Block                      Range
# 93                             Survey                   Abstract
# 94      Surface Hole Latitude (NAD27)                      Block
# 95     Surface Hole Longitude (NAD27)                     Survey
# 96       Bottom Hole Latitude (NAD27)                   OCS Area
# 97      Bottom Hole Longitude (NAD27)                   PGC Area
# 98                                UWI   Surface Latitude (WGS84)
# 99                                NaN  Surface Longitude (WGS84)
# 100                               NaN          Reported Operator
# 101                               NaN                Last 12 Oil
# 102                               NaN                Last 12 Gas
# 103                               NaN              Last 12 Water
# 104                               NaN                  Entity ID
#
#     PRODUCTION TIME SERIES DATA  WELL TEST DATA        FORMATION TOP DATA
# 0                           NaN             NaN                       NaN
# 1                     Entity ID             API                       API
# 2                       API/UWI       Test Date                 Formation
# 3                  API/UWI List  Test Formation          Formation Top MD
# 4       Monthly Production Date       Test Type         Formation Top TVD
# 5                   Monthly Oil   Liquid Volume     Formation Top Unknown
# 6                   Monthly Gas      Gas Volume  Formation Bottom Unknown
# 7                 Monthly Water    Water Volume                     Field
# 8                    Well Count    Hours Tested            State Province
# 9                          Days             NaN                Basin Name
# 10                Daily Avg Oil             NaN                       NaN
# 11                Daily Avg Gas             NaN                       NaN
# 12              Daily Avg Water             NaN                       NaN
# 13                    Reservoir             NaN                       NaN
# 14              Well/Lease Name             NaN                       NaN
# 15                  Well Number             NaN                       NaN
# 16               Operator Alias             NaN                       NaN
# 17              Production Type             NaN                       NaN
# 18            Production Status             NaN                       NaN
# 19                  Entity Type             NaN                       NaN
# 20                          NaN             NaN                       NaN
# 21                          NaN             NaN                       NaN
# 22                          NaN             NaN                       NaN
# 23                          NaN             NaN                       NaN
# 24                          NaN             NaN                       NaN
# 25                          NaN             NaN                       NaN
# 26                          NaN             NaN                       NaN
# 27                          NaN             NaN                       NaN
# 28                          NaN             NaN                       NaN
# 29                          NaN             NaN                       NaN
# ..                          ...             ...                       ...
# 75                          NaN             NaN                       NaN
# 76                          NaN             NaN                       NaN
# 77                          NaN             NaN                       NaN
# 78                          NaN             NaN                       NaN
# 79                          NaN             NaN                       NaN
# 80                          NaN             NaN                       NaN
# 81                          NaN             NaN                       NaN
# 82                          NaN             NaN                       NaN
# 83                          NaN             NaN                       NaN
# 84                          NaN             NaN                       NaN
# 85                          NaN             NaN                       NaN
# 86                          NaN             NaN                       NaN
# 87                          NaN             NaN                       NaN
# 88                          NaN             NaN                       NaN
# 89                          NaN             NaN                       NaN
# 90                          NaN             NaN                       NaN
# 91                          NaN             NaN                       NaN
# 92                          NaN             NaN                       NaN
# 93                          NaN             NaN                       NaN
# 94                          NaN             NaN                       NaN
# 95                          NaN             NaN                       NaN
# 96                          NaN             NaN                       NaN
# 97                          NaN             NaN                       NaN
# 98                          NaN             NaN                       NaN
# 99                          NaN             NaN                       NaN
# 100                         NaN             NaN                       NaN
# 101                         NaN             NaN                       NaN
# 102                         NaN             NaN                       NaN
# 103                         NaN             NaN                       NaN
# 104                         NaN             NaN                       NaN
#
# [105 rows x 5 columns]

# %% [markdown]
# The Wells data has the majority of columns of interest, and the Production data looks like a much more detailed version of the production data from the COGCC database, which could be interesting, but it was suggested that I look at the first 6 months of production, so I don't need this additional detail.  Finally, the production time series data could be interesting to do modeling using time series to predict future production after that time. The Formations and Test data sets are not very important in this analysis as each well in the Wells data already includes the target formation, and tests do not provide much quality data for our analysis. Let's first look at the Wells dataset.
# ### Wells Data

# %%
# Read in Wells Data for Horizontal wells
wells = pd.read_csv('1a_Frac_Capstone/DJHZ6-17-18Wells.CSV')
wells.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (0,1,2,11,35,36,37,38,39,44,81,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            API10            API12              API14        Well Name  \
# 0  ="0500506864"  ="050050686400"  ="05005068640000"      KISSLER DAN
# 1  ="0500506866"  ="050050686600"  ="05005068660000"      STATE-CRAIG
# 2  ="0500506867"  ="050050686700"  ="05005068670000"         LINNEBUR
# 3  ="0500506870"  ="050050687000"  ="05005068700000"  COLUMBINE-STATE
# 4  ="0500506876"  ="050050687600"  ="05005068760000"      STATE-CRAIG
#
#   Well Number       Lease Name      Operator Alias       Reported Operator  \
# 0        2-10      KISSLER DAN                 S&D               S & D LLC
# 1        2-16      STATE-CRAIG  OVERLAND RESOURCES  OVERLAND RESOURCES LTD
# 2        1-20         LINNEBUR  OVERLAND RESOURCES  OVERLAND RESOURCES LTD
# 3           2  COLUMBINE-STATE         AXIS ENERGY    AXIS EXPLORATION LLC
# 4        3-16      STATE-CRAIG  OVERLAND RESOURCES  OVERLAND RESOURCES LTD
#
#        Field  County/Parish         ...         Quarter Quarter District  \
# 0    CHALICE  ARAPAHOE (CO)         ...                    SWSW      NaN
# 1  PRONGHORN  ARAPAHOE (CO)         ...                    SESW      NaN
# 2  PRONGHORN  ARAPAHOE (CO)         ...                    SESE      NaN
# 3    CHALICE  ARAPAHOE (CO)         ...                    SENE      NaN
# 4  PRONGHORN  ARAPAHOE (CO)         ...                    SWSE      NaN
#
#    Abstract  Block  Survey  Surface Hole Latitude (NAD27)  \
# 0       NaN    NaN     NaN                      39.712224
# 1       NaN    NaN     NaN                      39.609786
# 2       NaN    NaN     NaN                      39.595196
# 3       NaN    NaN     NaN                      39.706044
# 4       NaN    NaN     NaN                      39.609906
#
#   Surface Hole Longitude (NAD27) Bottom Hole Latitude (NAD27)  \
# 0                    -104.543270                    39.712224
# 1                    -104.334593                    39.609786
# 2                    -104.344133                    39.595196
# 3                    -104.547569                    39.706044
# 4                    -104.330093                    39.609906
#
#   Bottom Hole Longitude (NAD27)                 UWI
# 0                   -104.543270  ="05-005-06864-00"
# 1                   -104.334593  ="05-005-06866-00"
# 2                   -104.344133  ="05-005-06867-00"
# 3                   -104.547569  ="05-005-06870-00"
# 4                   -104.330093  ="05-005-06876-00"
#
# [5 rows x 99 columns]

# %% [markdown]
# Alright, this is some fairly clean data, but I already see a couple of spots that need cleaning, such as API numbers, and some columns that might need to be dropped because of their lack of data.  Let's now check out all of the columns in this data set.

# %%
wells.columns
# Out:
# Index(['API10', 'API12', 'API14', 'Well Name', 'Well Number', 'Lease Name',
#        'Operator Alias', 'Reported Operator', 'Field', 'County/Parish',
#        'Target Formation', 'DI Landing Zone', 'KB Elevation',
#        'Ground Elevation', 'Measured Depth (TD)', 'True Vertical Depth',
#        'Production Type', 'Well Status', 'Spud Date', 'Completion Date',
#        'Drill Type', 'Upper Perforation', 'Lower Perforation',
#        'Gross Perforated Interval', 'Horizontal Length',
#        'Wellbore Count (API10)', 'Completion Count (API10)',
#        'Treatment Job Count (API10)', 'First Prod Date',
#        'Start Date (First Treatment Job)', 'End Date (First Treatment Job)',
#        'First Test Gas Volume', 'First Test Oil Volume',
#        'First Test Water Volume', 'First Test Hours Tested',
#        'First Test Production Method', 'First Well Test Date',
#        'First Reported Test Type', 'Last Well Test Date', 'Last Test Type',
#        'First Test Gas Gravity', 'First Test Oil Gravity', 'First Test GOR',
#        'First Test Casing Pressure', 'First Test Choke Size',
#        'First Test Flowing Tubing Pressure', 'Peak BOE', 'Peak Gas',
#        'Peak Oil', 'Peak BOE per perforated Ft', 'Peak Gas per perforated Ft',
#        'Peak Oil per perforated Ft', 'Cum BOE', 'Cum Gas', 'Cum Oil',
#        'Cum Water', 'First 6 BOE', 'First 6 Gas', 'First 6 Oil',
#        'First 6 Water', 'First 6 BOE per perforated Ft',
#        'First 6 Gas per perforated Ft', 'First 6 Oil per perforated Ft',
#        'First 12 BOE', 'First 12 Gas', 'First 12 Oil', 'First 12 Water',
#        'First 12 BOE per perforated Ft', 'First 12 Gas per perforated Ft',
#        'First 12 Oil per perforated Ft', 'First 24 BOE', 'First 24 Gas',
#        'First 24 Oil', 'First 24 Water', 'First 60 BOE', 'First 60 Gas',
#        'First 60 Oil', 'First 60 Water', 'Has Digitized Trajectory (Y/N)',
#        'Has Well Log (LAS) (Y/N)', 'Has Well Log (Raster) (Y/N)',
#        'LAS Mnemonics', 'Country', 'Basin', 'Play Assessment Basin', 'State',
#        'Section', 'Township', 'Range', 'Quarter Quarter', 'District',
#        'Abstract', 'Block', 'Survey', 'Surface Hole Latitude (NAD27)',
#        'Surface Hole Longitude (NAD27)', 'Bottom Hole Latitude (NAD27)',
#        'Bottom Hole Longitude (NAD27)', 'UWI'],
#       dtype='object')

# %% [markdown]
# Columns I'm interested in and an explanation of what they contain:
# - API14 - Well ID
# - Well Name - Name of the well
# - Well Number - Number of well name
# - Operator Alias - Company Name
# - Field - General location
# - Target Formation - Type of Rock that is being drilled/fraced
# - Measured Depth (TD) - Total depth of well (vertical + horizontal distance)
# - True Vertical Depth - Vertical depth of well
# - Drill Type - Type of well (vertical, horizontal, or distributed)
# - Upper Perforation - Depth of first perforation (mostly for vertical wells)
# - Lower Perforation - Depth of last perforation (mostly for horizontal wells)
# - Gross Perforated Interval - How frequent the cement was perforated
# - Horizontal Length - Length of the horizontal portion of the well
# - Treatment Job Count (API10) - The number of times the well was fraced
# - Cum BOE - Cumulative Barrels of Oil Equivalent (from oil and gas produced)
# - Cum Gas - Cumulative gas produced
# - Cum Oil - Cumulative oil produced
# - First 6 BOE - Barrels of oil equvalent produced in first 6 months of production
# - Township - Location North and South of base line
# - Range - Location East and West of meridian

# %%
# Create new wells data frame with only columns of interest and horizontal drill types.
wells1 = wells[['API14', 
                'Well Name',
                'Well Number',
                'Operator Alias', 
                'Field',
                'Target Formation', 
                'Measured Depth (TD)',
                'True Vertical Depth', 
                'Drill Type',
                'Upper Perforation', 
                'Lower Perforation',
                'Gross Perforated Interval', 
                'Horizontal Length', 
                'Treatment Job Count (API10)',
                'Cum BOE', 
                'Cum Gas', 
                'Cum Oil', 
                'First 6 BOE', 
                'First Prod Date', 
                'Township', 
                'Range',
                     ]]
hzwells = wells1[wells1['Drill Type'] == 'H']
hzwells.head()
# Out:
#                    API14                  Well Name Well Number  \
# 6002   ="05123192590000"                 BRINGELSON       1-28X
# 10040  ="05005072210100"              STATE MASSIVE          1H
# 10059  ="05005073270100"  STATE CHALLENGER 5-65 2-3        3BYH
# 15865  ="05123343680100"                  BARRACUDA  29-11-7-60
# 16075  ="05123351000100"               RAINDANCE FC    23-369HC
#
#                   Operator Alias                   Field Target Formation  \
# 6002   PETERSON ENERGY OPERATING                 NEW DAY         NIOBRARA
# 10040            CONOCO PHILLIPS  DJ HORIZONTAL NIOBRARA         NIOBRARA
# 10059            CONOCO PHILLIPS                 WILDCAT         NIOBRARA
# 15865       VERDAD RESOURCES LLC                 WILDCAT         NIOBRARA
# 16075    GREAT WESTERN OPERATING              WATTENBERG           CODELL
#
#        Measured Depth (TD)  True Vertical Depth Drill Type  Upper Perforation  \
# 6002                7630.0               5827.0          H             6185.0
# 10040              17291.0               8008.0          H                NaN
# 10059              17847.0               7983.0          H                NaN
# 15865              10697.0               6351.0          H                NaN
# 16075              20186.0               6580.0          H                NaN
#
#        ...   Gross Perforated Interval  Horizontal Length  \
# 6002   ...                      1230.0                NaN
# 10040  ...                         NaN                NaN
# 10059  ...                         NaN                NaN
# 15865  ...                         NaN                NaN
# 16075  ...                         NaN                NaN
#
#        Treatment Job Count (API10)  Cum BOE  Cum Gas  Cum Oil  First 6 BOE  \
# 6002                           1.0    474.0      0.0    474.0        448.0
# 10040                          NaN      NaN      NaN      NaN          NaN
# 10059                          NaN      NaN      NaN      NaN          NaN
# 15865                          NaN      NaN      NaN      NaN          NaN
# 16075                          NaN      NaN      NaN      NaN          NaN
#
#        First Prod Date Township Range
# 6002        1997-03-01   ="09N"   58W
# 10040              NaN   ="05S"   65W
# 10059              NaN   ="05S"   65W
# 15865              NaN   ="07N"   60W
# 16075              NaN   ="06N"   67W
#
# [5 rows x 21 columns]

# %% [markdown]
# Great - now only having the columns of interest, I can zoom in on the data that is relevant to this project to see what needs to be cleaned, what is missing, etc.

# %%
hzwells.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15092 entries, 6002 to 60908
# Data columns (total 21 columns):
# API14                          15092 non-null object
# Well Name                      15092 non-null object
# Well Number                    15092 non-null object
# Operator Alias                 14312 non-null object
# Field                          15092 non-null object
# Target Formation               15092 non-null object
# Measured Depth (TD)            14242 non-null float64
# True Vertical Depth            12006 non-null float64
# Drill Type                     15092 non-null object
# Upper Perforation              4987 non-null float64
# Lower Perforation              4986 non-null float64
# Gross Perforated Interval      4983 non-null float64
# Horizontal Length              15068 non-null float64
# Treatment Job Count (API10)    6624 non-null float64
# Cum BOE                        6265 non-null float64
# Cum Gas                        6233 non-null float64
# Cum Oil                        6259 non-null float64
# First 6 BOE                    5811 non-null float64
# First Prod Date                6328 non-null object
# Township                       15092 non-null object
# Range                          15092 non-null object
# dtypes: float64(11), object(10)
# memory usage: 2.5+ MB

# %% [markdown]
# Alright, it looks like there are about 6K entries that include the first 6 months of BOE, which will be my target output at least to start.  The other wells must be pre-production, didn't track this value, or did not produce.  Let's pull out these wells.

# %%
hzwells_pr = hzwells[hzwells['First 6 BOE'] >0]
hzwells_pr.head()
# Out:
#                    API14   Well Name   Well Number             Operator Alias  \
# 6002   ="05123192590000"  BRINGELSON         1-28X  PETERSON ENERGY OPERATING
# 17938  ="05001097530000"         WEP  4-28-11-3-64                AXIS ENERGY
# 17940  ="05001097540000"         WEP  1-28-11-3-64                AXIS ENERGY
# 17955  ="05001098010000"       SHARP     24-3-11HC                  WARD PETR
# 17977  ="05001098260000"      ALICIA     12-15H-5N                  WARD PETR
#
#                         Field Target Formation  Measured Depth (TD)  \
# 6002                  NEW DAY         NIOBRARA               7630.0
# 17938  DJ HORIZONTAL NIOBRARA         NIOBRARA              11431.0
# 17940  DJ HORIZONTAL NIOBRARA         NIOBRARA              11715.0
# 17955              WATTENBERG           CODELL              10161.0
# 17977                 SPINDLE         NIOBRARA              13842.0
#
#        True Vertical Depth Drill Type  Upper Perforation  ...   \
# 6002                5827.0          H             6185.0  ...
# 17938               7551.0          H             7519.0  ...
# 17940               7594.0          H             8151.0  ...
# 17955               7774.0          H                NaN  ...
# 17977               7821.0          H                NaN  ...
#
#        Gross Perforated Interval  Horizontal Length  \
# 6002                      1230.0                NaN
# 17938                     3912.0            4376.37
# 17940                     3564.0            3575.27
# 17955                        NaN            2247.84
# 17977                        NaN            5524.53
#
#        Treatment Job Count (API10)   Cum BOE   Cum Gas   Cum Oil  First 6 BOE  \
# 6002                           1.0     474.0       0.0     474.0        448.0
# 17938                          2.0   28664.0   45552.0   21072.0      10662.0
# 17940                          2.0   33546.0   60174.0   23517.0      13185.0
# 17955                          1.0  188242.0  273498.0  142659.0      46241.0
# 17977                          1.0  159344.0  348837.0  101205.0      53409.0
#
#        First Prod Date Township Range
# 6002        1997-03-01   ="09N"   58W
# 17938       2017-04-01   ="03S"   64W
# 17940       2013-02-01   ="03S"   64W
# 17955       2015-01-01   ="01S"   67W
# 17977       2015-09-01   ="01S"   68W
#
# [5 rows x 21 columns]

# %%
# Write DataFrame to csv for use in database
hzwells_pr.to_csv('1a_Frac_Capstone/HZwells.csv')

# %% [markdown]
# ### Production Time Series Data
# Next, let's take a look at the time series data to see what's there.

# %%
prod_time = pd.read_csv('1a_Frac_Capstone/dj hz 6-17-18 Production Time Series.csv')
print(prod_time.shape)
prod_time.tail()
# Out:
# (236016, 19)
#         Entity ID        API/UWI  API/UWI List Monthly Production Date  \
# 236011  104208052  5123144240000  5.123144e+10              1998-11-01
# 236012  104208052  5123144240000  5.123144e+10              1998-12-01
# 236013  104208052  5123144240000  5.123144e+10              1999-01-01
# 236014  104208052  5123144240000  5.123144e+10              1999-02-01
# 236015  104208052  5123144240000  5.123144e+10              1999-09-01
#
#         Monthly Oil  Monthly Gas  Monthly Water  Well Count  Days  \
# 236011         22.0        393.0            0.0           1   0.0
# 236012         22.0        387.0            0.0           1   0.0
# 236013         60.0        935.0            0.0           1  29.0
# 236014         49.0        705.0            0.0           1  28.0
# 236015          1.0          0.0            0.0           1  30.0
#
#         Daily Avg Oil  Daily Avg Gas  Daily Avg Water Reservoir  \
# 236011            0.0           13.0              0.0    CODELL
# 236012            0.0           12.0              0.0    CODELL
# 236013            2.0           32.0              0.0    CODELL
# 236014            1.0           25.0              0.0    CODELL
# 236015            0.0            0.0              0.0    CODELL
#
#        Well/Lease Name Well Number      Operator Alias Production Type  \
# 236011        HSR-KING        4-23  HS RESOURCES, INC.             OIL
# 236012        HSR-KING        4-23  HS RESOURCES, INC.             OIL
# 236013        HSR-KING        4-23  HS RESOURCES, INC.             OIL
# 236014        HSR-KING        4-23  HS RESOURCES, INC.             OIL
# 236015        HSR-KING        4-23  HS RESOURCES, INC.             OIL
#
#        Production Status Entity Type
# 236011          INACTIVE        WELL
# 236012          INACTIVE        WELL
# 236013          INACTIVE        WELL
# 236014          INACTIVE        WELL
# 236015          INACTIVE        WELL

# %% [markdown]
# Great.  I might explore this more in depth after my initial models to determine how production changes over time, not just the total of the first six months.

# %% [markdown]
# ## FracFocus Data
# The final set of data that I was provided was from a website called [FracFocus](http://fracfocusdata.org/), which contains data on the actual frac conditions for each well.  This data set was extremely large, so I processed it through SQL, including joining on the API number with the horizontal wells data and then exported the resultant csv.
#
# ### SQL Query
# `SELECT
# SUBSTR(Wells.API14, 3, 14) APIclean,
# Wells.*,
# sub.*,
# (sub.Slickwater + sub.Gel + sub.Crosslinked) totadditives
# FROM (
# SELECT APINumber,
# CAST(StateNumber as Integer) as StateNum,
# MAX(CASE WHEN Purpose LIKE '%friction%' THEN 1
# WHEN Purpose LIKE '%mobility%' THEN 1
# WHEN Purpose LIKE '%surfactant%' THEN 1
# WHEN Purpose LIKE '%flow%' THEN 1
# WHEN Purpose LIKE '%breaker%' THEN 1 ELSE 0 END) as 'Slickwater',
# MAX(CASE WHEN Purpose LIKE '%gel%' THEN 1 ELSE 0 END) as 'Gel',
# MAX(CASE WHEN Purpose LIKE '%cross%' THEN 1
# WHEN Purpose LIKE '%x-link%' THEN 1
# WHEN Purpose LIKE '%initiator%' THEN 1
# WHEN Purpose LIKE '%guar%' THEN 1
# WHEN Purpose LIKE '%catalyst%' THEN 1 ELSE 0 END) as 'Crosslinked'
# FROM FracFocusRegistry Frac
# WHERE StateNum = 5
# GROUP BY APINumber
# ) sub
# JOIN HZWells Wells
# ON APIclean = sub.APINumber
# WHERE totadditives >0`

# %%
# Read in new wells data with frac conditions
frac_wells = pd.read_csv('1a_Frac_Capstone/FracTypeWells.csv')
frac_wells.head()
# Out:
#         APIclean  field1              API14     WellName       WellNumber  \
# 0  5001098010000   17955  ="05001098010000"        SHARP        24-3-11HC
# 1  5001097850000   17984  ="05001097850000"  STATE OF CO  1S-66-36-1609CH
# 2  5001097830000   17986  ="05001097830000"  STATE OF CO  1S-66-36-0108BH
# 3  5001097820000   17987  ="05001097820000"  STATE OF CO  1S-66-36-0108CH
# 4  5001097810000   17988  ="05001097810000"  STATE OF CO  1S-66-36-1609BH
#
#     OperatorAlias        Field TargetFormation  MeasuredDepth(TD)  \
# 0       WARD PETR   WATTENBERG          CODELL           10161.00
# 1  EXTRACTION O&G  THIRD CREEK        NIOBRARA           12177.31
# 2  EXTRACTION O&G  THIRD CREEK        NIOBRARA           12164.98
# 3  EXTRACTION O&G   WATTENBERG        NIOBRARA           12194.70
# 4  EXTRACTION O&G  THIRD CREEK        NIOBRARA           12117.48
#
#    TrueVerticalDepth      ...      First6BOE  FirstProdDate  Township  Range  \
# 0            7774.00      ...        46241.0     2015-01-01    ="01S"    67W
# 1            7576.73      ...         7094.0     2014-06-01    ="01S"    66W
# 2            7511.68      ...         8304.0     2014-06-01    ="01S"    66W
# 3            7574.72      ...         7118.0     2014-06-01    ="01S"    66W
# 4            7513.70      ...        10385.0     2014-06-01    ="01S"    66W
#
#        APINumber  StateNum  Slickwater  Gel  Crosslinked  totadditives
# 0  5001098010000         5           1    1            1             3
# 1  5001097850000         5           1    1            1             3
# 2  5001097830000         5           1    1            1             3
# 3  5001097820000         5           1    1            1             3
# 4  5001097810000         5           1    1            1             3
#
# [5 rows x 29 columns]

# %% [markdown]
# Awesome, let's check out what's in this dataset now and what we have to clean and what missing data we have.

# %%
frac_wells.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4520 entries, 0 to 4519
# Data columns (total 29 columns):
# APIclean                    4520 non-null int64
# field1                      4520 non-null int64
# API14                       4520 non-null object
# WellName                    4520 non-null object
# WellNumber                  4520 non-null object
# OperatorAlias               4520 non-null object
# Field                       4520 non-null object
# TargetFormation             4520 non-null object
# MeasuredDepth(TD)           4512 non-null float64
# TrueVerticalDepth           4510 non-null float64
# DrillType                   4520 non-null object
# UpperPerforation            3710 non-null float64
# LowerPerforation            3710 non-null float64
# GrossPerforatedInterval     3710 non-null float64
# HorizontalLength            4519 non-null float64
# TreatmentJobCount(API10)    4519 non-null float64
# CumBOE                      4520 non-null float64
# CumGas                      4520 non-null float64
# CumOil                      4520 non-null float64
# First6BOE                   4520 non-null float64
# FirstProdDate               4520 non-null object
# Township                    4520 non-null object
# Range                       4520 non-null object
# APINumber                   4520 non-null int64
# StateNum                    4520 non-null int64
# Slickwater                  4520 non-null int64
# Gel                         4520 non-null int64
# Crosslinked                 4520 non-null int64
# totadditives                4520 non-null int64
# dtypes: float64(11), int64(8), object(10)
# memory usage: 1.0+ MB

# %% [markdown]
# Aside from the perforation data and a few measured depths, we have all of the other relevant data ready for some cleaning and further analysis!
